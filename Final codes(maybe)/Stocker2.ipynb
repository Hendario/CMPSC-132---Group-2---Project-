# %%
import yfinance as yf
import pandas as pd

# %%
data = yf.download('MSFT', period = '5y')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
len(data)
# Out:
# 1258

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2016-04-29  49.349998  50.250000  49.349998  49.869999  45.729378  48411700
# 2016-05-02  50.000000  50.750000  49.779999  50.610001  46.407951  33114500
# 2016-05-03  50.340000  50.410000  49.599998  49.779999  45.646847  26460200
# 2016-05-04  49.840000  50.060001  49.459999  49.869999  45.729378  24257600
# 2016-05-05  49.869999  50.299999  49.730000  49.939999  45.793564  25390700

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-04-22  260.209991  261.779999  255.639999  257.170013  257.170013
# 2021-04-23  257.880005  261.510010  257.269989  261.149994  261.149994
# 2021-04-26  261.660004  262.440002  260.170013  261.549988  261.549988
# 2021-04-27  261.579987  263.190002  260.119995  261.970001  261.970001
# 2021-04-28  256.078003  256.539886  252.949997  254.559998  254.559998
#
#               Volume
# Date
# 2021-04-22  25606200
# 2021-04-23  21462600
# 2021-04-26  19763300
# 2021-04-27  30574500
# 2021-04-28  45794535

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2016-04-29 to 2021-04-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Adj Close  1258 non-null   float64
#  5   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.8 KB

# %%
data.loc[pd.datetime(2021,4,28)]
# Out:
# <ipython-input-56-4f59490b0ee9>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   data.loc[pd.datetime(2021,4,28)]
# Open         2.560780e+02
# High         2.565399e+02
# Low          2.529500e+02
# Close        2.545600e+02
# Adj Close    2.545600e+02
# Volume       4.579454e+07
# Name: 2021-04-28 00:00:00, dtype: float64

# %%
price = alt.Chart(data.reset_index()).mark_line().encode(
    x = 'Data:T',
    y = 'Close',
    tooltip = ['Date','Open','Close','High','Low','Volume']
).properties(
    width=600,height=200)

price
# Out:
# alt.Chart(...)

# %%
volume = alt.Chart(data.reset_index()).mark_line().encode(
    x = 'Data:T',
    y = 'Volume'
).properties(
    width=600,height=200)

volume
# Out:
# alt.Chart(...)

# %%
data.to_csv('msft.csv')
